# %%
name = input('Enter you name: ')
age = int(input("Enter your age"))

def name_call():
    print(f'Hey {name}, Welcome to Git. You are {age} years old ')
    
name_call()
# Out:
# Enter you name: Shreyas
# Enter your age20
# Hey Shreyas, welcome to Git. You are 20 years old
