# %%
num1 , num2 = input('Enter two numbers you want to multiply: ').split()
product = int(num1)*int(num2)

print(f'The product of the given numbers is {product}')
# Out:
# Enter two numbers you want to multiply: 5 9
# The product of the given numbers is 45
